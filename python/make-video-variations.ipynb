# %%
import os

def make_frame_sequence(src,dest):
    if not os.path.exists(dest):
        os.mkdir(dest)
        png_file_path = os.path.join(dest,'frame%06d.png')
        os.system(f'ffmpeg -i {src} -vf fps=30 {png_file_path}')

def make_video_variations(input):
    # get basename for folders, etc.
    basename = os.path.basename(input).split('.')[0]

    # prefix needed for folder navigation
    to_data_folder = '../bin/data'

    # make basename folder
    if not os.path.exists(os.path.join(to_data_folder,basename)):
        os.mkdir(os.path.join(to_data_folder,basename))

    # full size images
    make_frame_sequence(os.path.join(to_data_folder,input),os.path.join(to_data_folder,basename,'frames'))

    # small video
    mini_path = os.path.join(to_data_folder,basename,'mini.mp4')
    if not os.path.exists(mini_path):
        cropped_path = os.path.join(to_data_folder,basename,'cropped.mp4')
        os.system(f'ffmpeg -i {os.path.join(to_data_folder,input)} -vf crop=ih:ih {cropped_path}')
        os.system(f'ffmpeg -i {cropped_path} -vf scale=32:32 {mini_path}')
        os.system(f'rm {cropped_path}')

    # small images
    make_frame_sequence(mini_path,os.path.join(to_data_folder,basename,'mini-frames'))

    # hap video
    hap_path = os.path.join(to_data_folder,basename,'hap.mov')
    if not os.path.exists(hap_path):
        os.system(f'ffmpeg -i {os.path.join(to_data_folder,input)} -vcodec hap_alpha {hap_path}')

# file to process
inputs = ['west-rock-stylegan-tiled.mp4']

for input in inputs:
    make_video_variations(input)
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/west-rock-stylegan-tiled.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2023-07-29T15:50:00.000000Z
#   Duration: 00:01:00.35, start: 0.000000, bitrate: 79924 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 3840x2160 [SAR 1:1 DAR 16:9], 79557 kb/s, 29.99 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> tiff (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '../bin/data/west-rock-stylegan-tiled/frames/frame%06d.tif':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: tiff, yuv420p(tv, bt709, progressive), 3840x2160 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 tiff
# frame= 1811 fps= 87 q=-0.0 Lsize=N/A time=00:01:00.33 bitrate=N/A speed= 2.9x    ts/s speed=N/A
# video:18646766kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/west-rock-stylegan-tiled.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2023-07-29T15:50:00.000000Z
#   Duration: 00:01:00.35, start: 0.000000, bitrate: 79924 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 3840x2160 [SAR 1:1 DAR 16:9], 79557 kb/s, 29.99 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x11c705c70] using SAR=1/1
# [libx264 @ 0x11c705c70] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x11c705c70] profile High, level 5.0, 4:2:0, 8-bit
# [libx264 @ 0x11c705c70] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../bin/data/west-rock-stylegan-tiled/cropped.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 2160x2160 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame= 1811 fps= 46 q=-1.0 Lsize=  156834kB time=00:01:00.33 bitrate=21295.7kbits/s speed=1.52x
# video:156751kB audio:17kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042342%
# [libx264 @ 0x11c705c70] frame I:8     Avg QP:17.27  size:722664
# [libx264 @ 0x11c705c70] frame P:475   Avg QP:22.12  size:266015
# [libx264 @ 0x11c705c70] frame B:1328  Avg QP:29.35  size: 21366
# [libx264 @ 0x11c705c70] consecutive B-frames:  0.8%  4.3%  0.2% 94.8%
# [libx264 @ 0x11c705c70] mb I  I16..4: 36.0% 29.1% 35.0%
# [libx264 @ 0x11c705c70] mb P  I16..4:  1.5%  1.2%  0.7%  P16..4: 19.9% 20.9% 15.9%  0.0%  0.0%    skip:39.9%
# [libx264 @ 0x11c705c70] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.9%  4.9%  1.3%  direct: 1.9%  skip:70.0%  L0:25.5% L1:37.3% BI:37.2%
# [libx264 @ 0x11c705c70] 8x8 transform intra:34.1% inter:63.1%
# [libx264 @ 0x11c705c70] coded y,uvDC,uvAC intra: 39.7% 55.1% 41.6% inter: 14.1% 11.8% 3.7%
# [libx264 @ 0x11c705c70] i16 v,h,dc,p: 69% 26%  4%  1%
# [libx264 @ 0x11c705c70] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 10% 47%  3%  4%  4%  3%  4%  6%
# [libx264 @ 0x11c705c70] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 12% 21%  6%  7%  8%  7%  7%  7%
# [libx264 @ 0x11c705c70] i8c dc,h,v,p: 51% 22% 22%  5%
# [libx264 @ 0x11c705c70] Weighted P-Frames: Y:9.7% UV:5.1%
# [libx264 @ 0x11c705c70] ref P L0: 62.6% 25.6%  9.0%  2.5%  0.2%
# [libx264 @ 0x11c705c70] ref B L0: 94.6%  4.3%  1.1%
# [libx264 @ 0x11c705c70] ref B L1: 97.6%  2.4%
# [libx264 @ 0x11c705c70] kb/s:21271.64
# [aac @ 0x11c706f10] Qavg: 65536.000
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/west-rock-stylegan-tiled/cropped.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:01:00.37, start: 0.000000, bitrate: 21283 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 2160x2160 [SAR 1:1 DAR 1:1], 21271 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x122f23510] using SAR=1/1
# [libx264 @ 0x122f23510] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x122f23510] profile High, level 1.0, 4:2:0, 8-bit
# [libx264 @ 0x122f23510] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=1 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../bin/data/west-rock-stylegan-tiled/mini.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 32x32 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame= 1811 fps=295 q=29.0 Lsize=     161kB time=00:01:00.33 bitrate=  21.9kbits/s speed=9.82x
# video:88kB audio:17kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 53.747585%
# [libx264 @ 0x122f23510] frame I:8     Avg QP:21.88  size:   642
# [libx264 @ 0x122f23510] frame P:1589  Avg QP:24.78  size:    51
# [libx264 @ 0x122f23510] frame B:214   Avg QP:34.13  size:    13
# [libx264 @ 0x122f23510] consecutive B-frames: 76.6% 22.7%  0.7%  0.0%
# [libx264 @ 0x122f23510] mb I  I16..4:  0.0% 43.8% 56.2%
# [libx264 @ 0x122f23510] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4: 75.8%  0.3%  0.9%  0.0%  0.0%    skip:22.9%
# [libx264 @ 0x122f23510] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 20.3%  0.0%  0.0%  direct: 0.0%  skip:79.7%  L0: 0.0% L1:100.0% BI: 0.0%
# [libx264 @ 0x122f23510] 8x8 transform intra:43.8% inter:39.6%
# [libx264 @ 0x122f23510] coded y,uvDC,uvAC intra: 100.0% 100.0% 100.0% inter: 39.1% 14.3% 8.2%
# [libx264 @ 0x122f23510] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 75% 11%  2%  0%  0%  0%  0%  0%
# [libx264 @ 0x122f23510] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 24% 10%  3%  7%  5%  7%  6% 13%
# [libx264 @ 0x122f23510] i8c dc,h,v,p: 53% 38%  9%  0%
# [libx264 @ 0x122f23510] Weighted P-Frames: Y:1.3% UV:0.0%
# [libx264 @ 0x122f23510] ref P L0: 91.7%  8.1%  0.2%  0.0%
# [libx264 @ 0x122f23510] kb/s:11.84
# [aac @ 0x122f247f0] Qavg: 65536.000
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/west-rock-stylegan-tiled/mini.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:01:00.37, start: 0.000000, bitrate: 21 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 32x32 [SAR 1:1 DAR 1:1], 11 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> tiff (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '../bin/data/west-rock-stylegan-tiled/mini-frames/frame%06d.tif':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: tiff, yuv420p(tv, bt709, progressive), 32x32 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 tiff
# frame= 1811 fps=0.0 q=-0.0 Lsize=N/A time=00:01:00.33 bitrate=N/A speed= 443x    ts/s speed=N/A
# video:3256kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/west-rock-stylegan-tiled.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2023-07-29T15:50:00.000000Z
#   Duration: 00:01:00.35, start: 0.000000, bitrate: 79924 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 3840x2160 [SAR 1:1 DAR 16:9], 79557 kb/s, 29.99 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hap (native))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1391a8000] [swscaler @ 0x162d80000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x162d90000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x163678000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x163688000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x163698000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x1636a8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x1636b8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x1636c8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x1636d8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x1636e8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x1636f8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x163708000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1391a8000] [swscaler @ 0x163718000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x158df0000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111208000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111218000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111228000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111238000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111248000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111258000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111268000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111278000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111288000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x111298000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x1112a8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1111f8000] [swscaler @ 0x1112b8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171e78000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171e88000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171e98000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171ea8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171eb8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171ec8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171ed8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171ee8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171ef8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171f08000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171f18000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171f28000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x163718000] [swscaler @ 0x171f38000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x1500d8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x1500e8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x1500f8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x150108000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x1437e8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x1437f8000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x143808000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x143818000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x143828000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x143838000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x143848000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x143858000] No accelerated colorspace conversion found from yuv420p to rgba.
# [swscaler @ 0x1437d8000] [swscaler @ 0x143868000] No accelerated colorspace conversion found from yuv420p to rgba.
# Output #0, mov, to '../bin/data/west-rock-stylegan-tiled/hap.mov':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: hap (Hap1 / 0x31706148), rgba(pc, gbr/bt709/bt709, progressive), 3840x2160 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 hap
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-07-29T15:50:00.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame= 1811 fps= 64 q=-0.0 Lsize= 4086455kB time=00:01:00.33 bitrate=554854.8kbits/s speed=2.14x
# video:4086386kB audio:17kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001278%
# [aac @ 0x107c078e0] Qavg: 65536.000
