# %%
import os

def make_frame_sequence(src,dest):
    if not os.path.exists(dest):
        os.mkdir(dest)
        tiff_file_path = os.path.join(dest,'frame%06d.tif')
        os.system(f'ffmpeg -i {src} -vf fps=30 {tiff_file_path}')

def make_video_variations(input):
    # get basename for folders, etc.
    basename = os.path.basename(input).split('.')[0]

    # prefix needed for folder navigation
    to_data_folder = '../bin/data'

    # make basename folder
    if not os.path.exists(os.path.join(to_data_folder,basename)):
        os.mkdir(os.path.join(to_data_folder,basename))

    # full size images
    make_frame_sequence(os.path.join(to_data_folder,input),os.path.join(to_data_folder,basename,'frames'))

    # small video
    mini_path = os.path.join(to_data_folder,basename,'mini.mp4')
    if not os.path.exists(mini_path):
        cropped_path = os.path.join(to_data_folder,basename,'cropped.mp4')
        os.system(f'ffmpeg -i {os.path.join(to_data_folder,input)} -vf crop=ih:ih {cropped_path}')
        os.system(f'ffmpeg -i {cropped_path} -vf scale=32:32 {mini_path}')
        os.system(f'rm {cropped_path}')

    # small images
    make_frame_sequence(mini_path,os.path.join(to_data_folder,basename,'mini-frames'))

    # hap video
    hap_path = os.path.join(to_data_folder,basename,'hap.mov')
    if not os.path.exists(hap_path):
        os.system(f'ffmpeg -i {os.path.join(to_data_folder,input)} -vcodec hap {hap_path}')

# file to process
inputs = ['slow-water.mp4']

for input in inputs:
    make_video_variations(input)
# Out:
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/5.0.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/slow-water.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2022-11-18T23:49:55.000000Z
#   Duration: 00:01:24.69, start: 0.000000, bitrate: 20326 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 20010 kb/s, 30 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> tiff (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '../bin/data/slow-water/frames/frame%06d.tif':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf59.16.100
#   Stream #0:0(eng): Video: tiff, yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 tiff
# frame= 2540 fps=108 q=-0.0 Lsize=N/A time=00:01:24.66 bitrate=N/A speed=3.59x
# video:7220880kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/5.0.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/slow-water.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2022-11-18T23:49:55.000000Z
#   Duration: 00:01:24.69, start: 0.000000, bitrate: 20326 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 20010 kb/s, 30 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fc42a8056c0] using SAR=1/1
# [libx264 @ 0x7fc42a8056c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fc42a8056c0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x7fc42a8056c0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../bin/data/slow-water/cropped.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf59.16.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1080x1080 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 aac
# frame= 2540 fps= 47 q=-1.0 Lsize=   23139kB time=00:01:24.67 bitrate=2238.7kbits/s speed=1.58x
# video:23023kB audio:24kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.401588%
# [libx264 @ 0x7fc42a8056c0] frame I:11    Avg QP:21.05  size: 33534
# [libx264 @ 0x7fc42a8056c0] frame P:638   Avg QP:23.75  size: 20448
# [libx264 @ 0x7fc42a8056c0] frame B:1891  Avg QP:25.29  size:  5373
# [libx264 @ 0x7fc42a8056c0] consecutive B-frames:  0.7%  0.0%  0.6% 98.7%
# [libx264 @ 0x7fc42a8056c0] mb I  I16..4: 21.7% 66.4% 11.9%
# [libx264 @ 0x7fc42a8056c0] mb P  I16..4: 15.9% 27.9%  2.7%  P16..4: 32.7% 11.1%  1.9%  0.0%  0.0%    skip: 7.8%
# [libx264 @ 0x7fc42a8056c0] mb B  I16..4:  0.7%  0.8%  0.1%  B16..8: 30.3%  4.3%  0.5%  direct: 1.7%  skip:61.5%  L0:41.3% L1:49.0% BI: 9.7%
# [libx264 @ 0x7fc42a8056c0] 8x8 transform intra:59.3% inter:85.2%
# [libx264 @ 0x7fc42a8056c0] coded y,uvDC,uvAC intra: 33.5% 54.8% 12.0% inter: 9.1% 11.2% 0.0%
# [libx264 @ 0x7fc42a8056c0] i16 v,h,dc,p: 10% 60%  8% 22%
# [libx264 @ 0x7fc42a8056c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 50% 23%  1%  2%  1% 10%  1%  3%
# [libx264 @ 0x7fc42a8056c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  9% 54% 14%  2%  4%  2% 13%  1%  3%
# [libx264 @ 0x7fc42a8056c0] i8c dc,h,v,p: 40% 49%  7%  3%
# [libx264 @ 0x7fc42a8056c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7fc42a8056c0] ref P L0: 68.9% 11.5% 14.6%  5.1%
# [libx264 @ 0x7fc42a8056c0] ref B L0: 95.1%  4.0%  0.9%
# [libx264 @ 0x7fc42a8056c0] ref B L1: 98.4%  1.6%
# [libx264 @ 0x7fc42a8056c0] kb/s:2227.56
# [aac @ 0x7fc42a806e80] Qavg: 65536.000
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/5.0.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/slow-water/cropped.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.16.100
#   Duration: 00:01:24.67, start: 0.000000, bitrate: 2238 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1080x1080 [SAR 1:1 DAR 1:1], 2227 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fe30d209b40] using SAR=1/1
# [libx264 @ 0x7fe30d209b40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fe30d209b40] profile High, level 1.0, 4:2:0, 8-bit
# [libx264 @ 0x7fe30d209b40] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=1 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../bin/data/slow-water/mini.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.16.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 32x32 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 aac
# frame= 2540 fps=499 q=29.0 Lsize=     219kB time=00:01:24.67 bitrate=  21.2kbits/s speed=16.6x
# video:123kB audio:24kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 50.021713%
# [libx264 @ 0x7fe30d209b40] frame I:11    Avg QP:21.27  size:   267
# [libx264 @ 0x7fe30d209b40] frame P:2514  Avg QP:24.13  size:    48
# [libx264 @ 0x7fe30d209b40] frame B:15    Avg QP:29.97  size:    16
# [libx264 @ 0x7fe30d209b40] consecutive B-frames: 98.9%  1.0%  0.1%  0.0%
# [libx264 @ 0x7fe30d209b40] mb I  I16..4:  0.0% 47.7% 52.3%
# [libx264 @ 0x7fe30d209b40] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4: 54.6% 20.7% 10.9%  0.0%  0.0%    skip:13.9%
# [libx264 @ 0x7fe30d209b40] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 45.0%  0.0%  1.2%  direct: 1.7%  skip:51.7%  L0:15.3% L1:83.8% BI: 0.9%
# [libx264 @ 0x7fe30d209b40] 8x8 transform intra:47.7% inter:41.6%
# [libx264 @ 0x7fe30d209b40] coded y,uvDC,uvAC intra: 100.0% 97.7% 95.5% inter: 46.2% 11.5% 3.0%
# [libx264 @ 0x7fe30d209b40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  1% 35% 30%  5%  4%  0% 12%  0% 14%
# [libx264 @ 0x7fe30d209b40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  2% 29% 26%  5%  4%  2% 15%  1% 15%
# [libx264 @ 0x7fe30d209b40] i8c dc,h,v,p: 84% 14%  0%  2%
# [libx264 @ 0x7fe30d209b40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7fe30d209b40] ref P L0: 87.5% 11.3%  1.1%  0.0%
# [libx264 @ 0x7fe30d209b40] kb/s:11.80
# [aac @ 0x7fe30d20b200] Qavg: 65536.000
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/5.0.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/slow-water/mini.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.16.100
#   Duration: 00:01:24.67, start: 0.000000, bitrate: 21 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 32x32 [SAR 1:1 DAR 1:1], 11 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> tiff (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '../bin/data/slow-water/mini-frames/frame%06d.tif':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.16.100
#   Stream #0:0(eng): Video: tiff, yuv420p(tv, bt709, progressive), 32x32 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 tiff
# frame= 2540 fps=2111 q=-0.0 Lsize=N/A time=00:01:24.66 bitrate=N/A speed=70.4x
# video:4566kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2.5)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/5.0.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../bin/data/slow-water.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2022-11-18T23:49:55.000000Z
#   Duration: 00:01:24.69, start: 0.000000, bitrate: 20326 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 20010 kb/s, 30 fps, 30 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hap (native))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mov, to '../bin/data/slow-water/hap.mov':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf59.16.100
#   Stream #0:0(eng): Video: hap (Hap1 / 0x31706148), rgba(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 hap
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-18T23:49:55.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 aac
# frame= 2540 fps= 22 q=-0.0 Lsize= 1536575kB time=00:01:24.67 bitrate=148663.3kbits/s speed=0.748x
# video:1536478kB audio:24kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004734%
# [aac @ 0x7f7b04a112c0] Qavg: 65536.000
